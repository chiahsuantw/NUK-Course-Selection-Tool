# %% [markdown]
# ## 套件引入

# %%
import bs4
import requests
import json

# %% [markdown]
# ## 學期更改
# * 更新資料改這邊就好

# %%
currentYear = 109
currentSemester = 2

# %% [markdown]
# ## 爬蟲程式碼
# * 感謝 110 級大學長的程式碼
# * 小弟在此邊上註解

# %%
Sclass = ['AM', 'LI', 'GL', 'IN', 'CCD', 'FI', 'AE', 'AB', 'LS', 'CDA', 'SC', 'WL', 'AP', 'GR', 'CCM', 'TODO', 'EL', 'KH', 'CS', 'IFD', 'IM', 'SO', 'AC', 'CD', 'CHS', 'FL', 'CC', 'EE', 'DA', 'DAP', 'CE', 'CM', 'LA']

all_course = [] #總課表

for sclass in Sclass:
    data = '<tr><td+width=""33%"">開課學年：' + str(currentYear) + '　　開課學期：第' + str(currentSemester) + '學期</td><td+width=""33%"">開課部別：大學部</td><td+width=""34%"">開課系所：無</td></tr><tr><td+width=""33%"">開課班級：無</td><td+width=""33%"">授課教師：無</td><td+width=""34%"">上課時間：無</td></tr>'
    req = requests.post('https://course.nuk.edu.tw/QueryCourse/QueryResult.asp', data = {'Condition':data,'Flag': 1,'OpenYear': currentYear,'Helf': currentSemester,'Pclass': 'A','Sclass': sclass,'Yclass': '','SirName': '','Sirno': '','WeekDay': '','Card': '','Subject': '','Language': '','Pre_Cono': '','Coname': ''})
    req.encoding = 'big5'
    soup = bs4.BeautifulSoup(req.text,'html.parser')
    soup = soup.find_all('tr')

    # i 是要略過非課程的資料
    i = 0

    for ele in soup:
        if i<=3:
            i+=1
            continue
        tdSet = ele.find_all('td')

        #微學分奇怪的格式 (更改: 用倒數二列的 微學分 來判斷)
        if "微學分" in tdSet[-2].text:
            continue    # 略過囉

        tempCourse = {}    # 存取課程的詳細資料[id, dept, name, grade, class, teacher, period, category, credit, location]
        tempCourse['id'] = tdSet[0].text.upper() + tdSet[1].text.upper()
        tempCourse['dept'] = sclass
        tempCourse['name'] = tdSet[5].text
        tempCourse['grade'] = tdSet[3].text
        tempCourse['class'] = tdSet[4].text
        tempCourse['teacher'] = tdSet[12].decode_contents()[0:-5].replace('<br/>',',')

        # 課程時間處理 以 list 存放多個時段
        course_time = []
        tempCourseTime = []
        print(tdSet[5].text, tdSet[12].text, tdSet[13].text, tdSet[14].text, tdSet[15].text)
        for i in range(14,21):
            if tdSet[i].text != '\u3000':    # 編碼問題
                for day in tdSet[i].text.split(','):
                    if day == 'X':
                        course_time.append([i-13, 0])
                    elif day == 'Y':
                        course_time.append([i-13, 4.5])   # 中午顯示 4.5
                    else:
                        try:
                            course_time.append([i-13, int(day)])
                        except ValueError:
                            print("Convert to int error: {}".format(day))    # 印出錯誤格式
                            pass

        tempCourse['period'] = course_time
        # 必修以 True 表示, 選修以 False
        if tdSet[7].text == '必':
            tempCourse['category'] = True
        else:
            tempCourse['category'] = False
        tempCourse['credit'] = tdSet[6].text
        tempCourse['location'] = tdSet[13].text

        # 放入字典
        all_course.append(tempCourse)

    # JSON存檔
    with open('AllCourse.json','w',encoding='utf8') as f:
        f.write(json.dumps(all_course, ensure_ascii=False).encode("utf8",errors='ignore').decode("utf8",errors='ignore'))
# Out:
# 泰 B01-204
#
#  程式設計與實習（二） 張保榮 C01-200 　 2,3,4
# if 微學分: False  禁止外加 限修
#  體育(二)-資工系 王士仁
#
#  資料結構 蘇家輝 C01-200
# if 微學分: False  限修
#  數位電路實驗 潘欣泰 C01-208 　 2,3,4
#
#  工程數學 殷堂凱 B01-B106
#
#  組合語言與系統程式 余亞儒 C01-200
# if 微學分: False  限修
#  java程式設計 余亞儒 C01-209 　 5,6,7
#
#  視窗程式設計 蘇家輝 C01-209 2,3,4
#
#  智慧財產權保護法制與實用 待公布 C01-B104
#
#  專題研究(一) 殷堂凱
#
#  作業系統 吳俊興 B01-105 2,3,4
# if 微學分: False  學程
#  軟體工程 林文揚 B01-204其他教室 6,7,8
#
#  影像處理 殷堂凱 C01-200其他教室 　 5,6,7
#
#  網路安全 陳建源 B01-204
#
#  人工智慧 蔡毓娟 L01-107
#
#  永續運算應用與實務 吳俊興 C01-209
#
#  智慧財產權保護法制與實用 待公布 C01-B104
# if 微學分: False  限修
#  資訊專題講座(二) 蘇家輝 C01-114
#
#  永續運算應用與實務 吳俊興 C01-209
# if 微學分: False  學程
#  物聯網 余亞儒郭錦福 C01-200
#
#  嵌入式多核心系統與軟體 郭錦福 C01-209其他教室 　 2,3,4
#
#  量子計算 陳建源 C01-114
#
#  醫學影像處理 殷堂凱 C01-200其他教室
#
#  醫療資訊學導論 林文揚潘欣泰殷堂凱 B01-108 2,3,4
#
#  計算機結構 郭錦福 C01-B102
# if 微學分: False  學程
#  深度學習 張保榮 C01-209 6,7,8
#
#  再生能源憑證制度：理論與實務 連興隆 C01-B102 2,3,4
#
#  永續運算應用與實務 吳俊興 C01-209
# if 微學分: False  限修學程
#  未來思考 連興隆 L01-202 　 5,6
# if 微學分: False  學程
#  資料設計思考 林杏子 L01-202 5,6,7
# if 微學分: True  微學分
#
#  社區設計與創新 莊淑姿 H1--106
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
#
#  社會企業創業專題 黃建源 C01-B107-1
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: False  學程
#  再生能源與設計思考 袁菁連興隆 L01-202
# if 微學分: False  先修學程
#  Unity 美術與開發實務 楊凱鳴陳怡兆 L01-610
# if 微學分: False  先修學程
#  Unreal 美術與開發實務 楊凱鳴陳怡兆 L01-610
# if 微學分: False  先修學程
#  EON腳本撰寫與開發實務 陳怡兆業界教師 L01-610
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: False  限修
#  電子商務 林杏子 M01-206
#
#  物聯網 蕭漢威 L01-203
#
#  無人載具設計與應用 蕭漢威 L01-203
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: True  禁止外加 微學分
# if 微學分: False  禁止外加 限修
#  體育(二)-資管系 高群超 　 　 3,4
# if 微學分: False  學程
#  資料設計思考 林杏子 L01-202 5,6,7
# if 微學分: False  限修
#  微積分 待公布 M01-201其他教室
# if 微學分: False  限修
#  會計學 楊書成 M01-205 　 5,6,7
# if 微學分: False  限修
#  物件導向程式設計Ⅰ 楊子賢 M01-201其他教室 　 8,9
# if 微學分: False  限修
#  資訊管理導論 王凱 M01-205
# if 微學分: False  學程
#  資料設計思考 林杏子 L01-202 5,6,7
# if 微學分: False  限修
#  物件導向程式設計Ⅰ 楊子賢 M01-201其他教室 　 8,9
# if 微學分: False  限修
#  統計學(二) 待公布 M01-206 　 2,3,4
# if 微學分: False  限修
#  資料庫管理 楊子賢 M01-105其他教室 　 5,6
# if 微學分: False  限修
#  電子商務 林杏子 M01-206
# if 微學分: False  限修
#  Python程式設計 蕭漢威 L01-108
# if 微學分: False  學程
#  資料設計思考 林杏子 L01-202 5,6,7
#
#  人力資源管理 郭英峰 M01-204 　 2,3,4
# if 微學分: False  限修
#  專案開發I(A) 王凱楊書成趙建雄林杏子郭英峰蕭漢威楊新章楊子賢待公布丁一賢 M01-205 2,3,4
# if 微學分: False  限修
#  作業系統 楊新章 M01-204 　 5,6,7
# if 微學分: False  限修
#  企業資源規劃與供應鏈管理 趙建雄 M01-205
# if 微學分: False  限修
#  進階網路協定與軟體定義網路 趙志宏 L01-108
#
#  行動商務 趙建雄 M01-205
# if 微學分: False  限修
#  Web 前端開發 黃威豪 M01-417 10,11,12
#
#  網絡數據分析實務 丁一賢 M01-417
#
#  社群網絡平台經營實務 楊書成 M01-108
#
#  深度學習導論 楊子賢 M01-205其他教室 8,9
#
#  管理數學 楊新章 M01-204
#
#  數位行銷 郭英峰 M01-204
#
#  物聯網 蕭漢威 L01-203
#
#  無人載具設計與應用 蕭漢威 L01-203
# if 微學分: False  學程
#  資料設計思考 林杏子 L01-202 5,6,7
# if 微學分: False  限修
#  Web 前端開發 黃威豪 M01-417 10,11,12
#
#  資訊科技與商業模式 王凱 M01-302
# if 微學分: False  限修
#  資料探勘與知識挖掘 待公布 M01-417
#
#  網絡數據分析實務 丁一賢 M01-417
#
#  社群網絡平台經營實務 楊書成 M01-108
# if 微學分: False  限修
#  深度學習導論 楊子賢 M01-205其他教室 8,9
# if 微學分: False  限修
#  深度學習應用實務 楊子賢 M01-417 　 3,4
#
#  管理數學 楊新章 M01-204
#
#  數位行銷 郭英峰 M01-204
#
#  物聯網 蕭漢威 L01-203
#
#  無人載具設計與應用 蕭漢威 L01-203
# if 微學分: False  限修學程
#  英文簡報技巧 王凱 M01-302
# if 微學分: False  禁止外加
#  生活經濟學 鄭義暉 M01-105 　 3,4
# if 微學分: False  禁止外加
#  性/別與法律 陳玫君 L02-101 　 10,11
# if 微學分: False  禁止外加
#  多元性別與親密關係 陳靜儀 B01-108
# if 微學分: False  禁止外加
#  國際會展公關禮儀 張秀瓊 M01-206
# if 微學分: False  禁止外加
#  領導統御 蔣遠平 C02-406
# if 微學分: False  禁止外加
#  孫子兵法 蔣遠平 C02-406
# if 微學分: False  禁止外加
#  自我管理與生涯規劃 曾榮豐 B01-109 8,9
# if 微學分: False  禁止外加
#  創意、創新與創業 鄭育仁 M01-204
# if 微學分: False  禁止外加
#  設計思考 李亭林 M01-205 5,6
# if 微學分: False  禁止外加
#  社會設計與方案規劃 陳靜儀 B01-105
# if 微學分: False  禁止外加
#  交通事故鑑定法規與案例解說 張永明 L02-103
# if 微學分: False  禁止外加
#  高大卓越講座 陳怡兆曾梓峰 L01-103 　 6,7
# if 微學分: False  禁止外加
#  媒體與公關實務 鄭為松 B01-106
# if 微學分: False  禁止外加
#  金融陷阱 蔡宗廷 L01-101
# if 微學分: False  禁止外加
#  人際關係 陳永安 B01-109
# if 微學分: False  禁止外加
#  壓力情緒管理 柯慈姍 B01-109 　 10,11
# if 微學分: False  禁止外加 限修
#  政府文書(公文寫作) 楊戊龍 L02-101 　 5,6
# if 微學分: False  禁止外加
#  民營化的迷思 蔡宗廷 L01-101
# if 微學分: False  禁止外加
#  智慧財產權 陳玫君 L02-106
# if 微學分: False  禁止外加
#  國際禮儀 陳永安 B01-101 3,4
# if 微學分: False  禁止外加
#  服務學習 余進忠 C02-107 9,10,11
# if 微學分: False  禁止外加
#  服務學習 陳靜儀 B01-105其他教室
# if 微學分: False  禁止外加
#  服務學習 朱朝煌 C02-108 9,10,11
# if 微學分: False  禁止外加
#  服務學習 吳孝慈 L01-101 5,6,7
# if 微學分: False  禁止外加
#  服務學習 游明珠 M01-102
# if 微學分: False  禁止外加
#  服務學習 陳致仁 B01-103
#
#  普通化學(二) 鄭秀英 C02-104
#
#  普通化學實驗(二) 李頂瑜 C02-203 2,3,4
#
#  普通物理實驗(二) 余進忠 C02-3004
#
#  普通物理(二) 孫士傑 C02-103 　 2,3,4
#
#  微積分(二) 張惠蘭 C02-406
#
#  分析化學 何永皓 C02-108 　 5,6,7
# if 微學分: False  禁止外加 限修
#  體育(二)-應化系 耿仕榮
#
#  有機化學(二) 郭文章 C02-108 2,3,4 1
#
#  有機化學實驗(二)A 黃榮宗 C02-203
#
#  有機化學實驗(二)B 周志明 C02-203 5,6,7
# if 微學分: False  限修
#  儀器分析實驗 劉福鯤 C02-101其他教室
# if 微學分: False  學程
#  奈米科技與應用 蔡振章 C02-211 　 5,6,7
#
#  物理化學(一) 陳振興 C02-105
#
#  無機化學(二) 莊琇惠 C02-105 5,6,7
#
#  物理化學(三) 待公布 C02-104
#
#  創意化學實驗(A) 莊曜遠 C02-103
#
#  創意化學實驗(B) 蔡振章 C02-211
#
#  專題研究(二) 何永皓黃榮宗蔡振章 C02-103
#
#  書報討論(一) 黃榮宗 C02-102
# if 微學分: False  學程
#  儀器分析(二) 何永皓 C02-108
# if 微學分: False  限修
#  書報討論(二) 莊曜遠 C02-211
#
#  業界實習2 陳振興 C02-103
# if 微學分: False  限修學程
#  質譜學 何永皓 C02-211
# if 微學分: False  學程
#  當代有機金屬化學 周志明 C02-211
# if 微學分: False  學程
#  無機光譜 李頂瑜 C02-211 　 2,3,4
#
#  計算化學 莊曜遠 C02-103 　 5,6,7
# if 微學分: False  學程
#  薄膜製程 劉福鯤 C02-103 8,9,10
# if 微學分: False  學程
#  真空技術 鄭秀英 C02-103
# if 微學分: False  限修學程
#  層析實作與應用 劉福鯤 C02-108 　 2,3,4
# if 微學分: False  學程
#  半導體微影製程概論 鄭秀英 C02-104 　 8,9,10
#
#  高分子科學概論 郭文章 C02-104
#
#  分子光物理化學及其應用 待公布 C02-103
#
#  有機合成反應的回顧與討論 黃榮宗 C02-106 2,3,4
#
#  有機逆合成分析 周志明 C02-211 2,3,4
# if 微學分: False  學程
#  儲能電池技術 陳振興 C02-211 5,6,7
#
#  全民國防教育軍事訓練課程-國際情勢 賴祥慶 L01-101 　 3,4
#
#  全民國防教育軍事訓練課程-國際情勢 賴祥慶 L01-101 　 5,6
# if 微學分: True  微學分
# if 微學分: True  微學分
# if 微學分: True  微學分
#
#  AI語意應用程式設計實作 曾智義 L01-108
# if 微學分: False  限修
#  刑法總則(二) 謝開平 L02-107 　 5,6
#
#  經濟學 待公布 L02-107 5,6,7
#
#  財政學 佘志民 L02-107
#
#  憲法(二) 簡玉聰 L02-107 　 3,4
#
#  民法總則(二) 邱泰錄 L02-108
# if 微學分: False  禁止外加 限修
#  體育(二)-財法系 蔡明書 　 3,4
#
#  民法物權(二) 曾千娟 L02-108
# if 微學分: False  限修
#  刑法分則(二) 謝開平 L02-204
#
#  行政法總論(二) 簡玉聰 L02-108 　 5,6,7
#
#  民法債編總論(二) 李淑如 L02-415-1 　 2,3,4
# if 微學分: False  學程
#  商事法總論及公司法 黃清溪 L02-204
#
#  民法繼承 呂麗慧 L02-202
#
#  刑事訴訟法(二) 張麗卿 L02-305
#
#  民法債編各論(二) 曾千娟 L02-108
#
#  刑事訴訟法(二)：理論應用與業界參訪 張麗卿 L02-305
#
#  刑事審判實務 陳明富 L02-108
# if 微學分: False  學程
#  租稅法總論 張永明 L02-108 　 3,4
# if 微學分: False  學程
#  專利法 周伯翰 L02-107
# if 微學分: False  學程
#  金融法 周伯翰 L02-201 　 6,7
#
#  海商法 林昭志 L02-202
#
#  民事訴訟法(二) 賴志強 L02-202 2,3,4
#
#  法學英文 謝國廉 L02-107
#
#  民法實例演習 林瑞成 L02-201 8,9
#
#  公法實例演習 張永明 L02-201
#
#  刑法實例演習 謝開平 L02-108
#
#  國際私法 曾千娟 L02-204-1 　 6,7
#
#  國際公法 吳行浩 L02-108 5,6
# if 微學分: False  學程
#  商標法 謝國廉 L02-107
# if 微學分: False  禁止外加
#  科普讀物導讀 高佑靈 C02-407 2,3,4
# if 微學分: False  禁止外加
#  科普讀物導讀 洪鼎惟 B01-101
# if 微學分: False  禁止外加
#  科普讀物導讀 胡忠信 B01-104 　 2,3,4
# if 微學分: False  禁止外加
#  科技與社會 林明良 B01-108 　 5,6,7
# if 微學分: False  禁止外加
#  科技與社會 倪麥童 B01-109 　 5,6,7
# if 微學分: False  禁止外加
#  科技與社會 許藝騰 B01-106 7,8,9
# if 微學分: False  禁止外加
#  科技與社會 洪靖 L02-103
# if 微學分: False  禁止外加
#  環境倫理 林師平 B01-104
# if 微學分: False  禁止外加
#  環境倫理 周孟麟 B01-103 　 2,3,4
# if 微學分: False  禁止外加
#  環境倫理 林淑文 B01-109
# if 微學分: False  禁止外加
#  環境倫理 林淑文 B01-109
# if 微學分: False  禁止外加
#  企業倫理 陳致仁 B01-103
# if 微學分: False  禁止外加
#  科技與工程倫理 許藝騰 B01-106 10,11,12
# if 微學分: False  禁止外加
#  科技與工程倫理 洪靖 L02-103其他教室
# if 微學分: False  禁止外加
#  邏輯思維與論證 陳今偉 H1--106
# if 微學分: False  禁止外加
#  邏輯思維與論證 陳維浩 M01-104
# if 微學分: False  禁止外加
#  哲學基本問題 陳德興 B01-106
# if 微學分: False  禁止外加
#  哲學基本問題 陳德興 B01-106
# if 微學分: False  禁止外加
#  哲學基本問題 陳今偉 L02-101
# if 微學分: False  禁止外加
#  哲學基本問題 陳維浩 M01-104
# if 微學分: False  禁止外加
#  哲學基本問題 黃頌竹 C02-105
# if 微學分: False  禁止外加
#  哲學基本問題 陳德興 B01-107
# if 微學分: False  禁止外加
#  藝術概論 林殷齊 B01-109
# if 微學分: False  禁止外加
#  藝術概論 陳姿菁 L01-103
# if 微學分: False  禁止外加
#  藝術概論 蔡佩玲 B01-106
# if 微學分: False  禁止外加
#  台灣藝術史 蔡佩玲 B01-106
# if 微學分: False  禁止外加
#  西洋藝術史概論 歐陽蒨 B01-107 　 5,6,7
# if 微學分: False  禁止外加
#  西洋藝術史概論 羅文秀 L01-103 7,8,9
# if 微學分: False  禁止外加
#  西洋藝術史概論 羅文秀 L01-103 　 2,3,4
# if 微學分: False  禁止外加
#  法律與人生 陳進郁 L02-204
# if 微學分: False  禁止外加
#  法律與人生 陳進郁 L02-204
# if 微學分: False  禁止外加
#  法律與人生 康�Y銘 L02-201 5,6,7
# if 微學分: False  禁止外加
#  媒體識讀與公民參與 洪聖斐 L02-101 2,3,4
# if 微學分: False  禁止外加
#  媒體識讀與公民參與 洪聖斐 B01-109
# if 微學分: False  禁止外加
#  媒體識讀與公民參與 藍美雅 B01-108
# if 微學分: False  禁止外加
#  媒體識讀與公民參與 藍美雅 B01-108
# if 微學分: False  禁止外加
#  全球化與多元文化 洪聖斐楊書濠 M01-105 5,6,7
# if 微學分: False  禁止外加
#  全球化與多元文化 陳俊昇 M01-205
# if 微學分: False  禁止外加
#  全球化與多元文化 劉子昱 B01-105
# if 微學分: False  禁止外加
#  全球化與多元文化 劉子昱 B01-105
# if 微學分: False  禁止外加
#  探索台灣－歷史篇 楊書濠 M01-105 2,3,4
# if 微學分: False  禁止外加
#  探索台灣－歷史篇 楊書濠 M01-105 10,11,12
# if 微學分: False  限修
#  計算機概論(二) 賴智錦 L01-107 　 2,3,4
# if 微學分: False  限修
#  普通物理學(二) 郭馨徽 B01-104
# if 微學分: False  限修
#  普通物理學實驗(二) 施明昌 C01-211
# if 微學分: False  限修
#  微積分(二) 黃祥哲 C01-B104 2,3,4
# if 微學分: False  限修
#  數位邏輯實驗 洪進華 C01-201其他教室
# if 微學分: False  限修
#  工程數學(一)(線性代數) 黃祥哲 C01-B104 　 5,6,7
# if 微學分: False  禁止外加 限修
#  體育(二)-電機A 馮潤賓
# if 微學分: False  限修
#  計算機概論(二) 吳志宏 L01-107 2,3,4
# if 微學分: False  限修
#  普通物理學(二) 馮瑞陽 C01-B104 　 2,3,4
# if 微學分: False  限修
#  普通物理學實驗(二) 施明昌 C01-211
# if 微學分: False  限修
#  數位邏輯實驗 洪進華 C01-201
# if 微學分: False  限修
#  工程數學(一)(線性代數) 龐一心 C01-B104
# if 微學分: False  限修
#  微積分(二) 鄧卜華 B01-105
# if 微學分: False  禁止外加 限修
#  體育(二)-電機B 高群超
# if 微學分: False  限修
#  電路學(二) 吳松茂 C01-B103
# if 微學分: False  限修
#  電子學(二) 洪進華 C01-202
# if 微學分: False  限修
#  電子電路工程實驗(二) 江德光 C01-301-1
# if 微學分: False  限修
#  電磁學(二) 郭馨徽 C01-B103
#
#  近代光學 施明昌 C01-B103
#
#  工程數學三(複變函數) 張文騰 C01-B103 2,3,4
#
#  組合語言 梁明正 C01-104 2,3,4
# if 微學分: False  限修
#  電路學(二) 江德光 C01-202 　 2,3,4
# if 微學分: False  限修
#  電子學(二) 陳春僥 C01-202其他教室 　 6,7
# if 微學分: False  限修
#  電子電路工程實驗(二) 陳春僥 C01-301-1
# if 微學分: False  限修
#  電磁學(二) 龐一心 C01-B103
#
#  近代光學 施明昌 C01-B103
#
#  工程數學三(複變函數) 張文騰 C01-B103 2,3,4
#
#  組合語言 梁明正 C01-104 2,3,4
#
#  電力系統分析 寧家慶 C01-B101 10,11,12
#
#  控制系統 黃祥哲 B01-105 　 2,3,4
#
#  固態物理導論 施明昌
# if 微學分: False  先修
#  通訊原理 徐忠枝 C01-B103
#
#  計算機組織 賴智錦 C01-414 2,3,4
# if 微學分: False  學程
#  半導體技術導論 葉文冠 C01-B103
#
#  電腦輔助電路設計 張文騰 C01-104 　 2,3,4
#
#  元件與微系統概論 張文騰 C01-414 5,6,7
# if 微學分: False  學程
#  真空技術 馮瑞陽 C01-B101
#
#  科技英文 郭馨徽 C01-B101-1 　 5,6,7
#
#  智能金屬製造實務研討 吳志宏賴智錦郭馨徽 B01-104 6,7,8
# if 微學分: False  先修
#  數位訊號處理、系統設計與模擬 徐忠枝 C01-201
#
#  光電子學(二) 馮瑞陽 C01-B101
#
#  微波被動電路設計與分析 鄧卜華 C01-104
#
#  微波電路概論與量測基礎實務 吳松茂 C01-414
#
#  仿生計算 賴智錦 C01-414
# if 微學分: False  先修
#  射頻主動電路設計 龐一心 C01-104
#
#  深度學習與智慧型機械人 吳志宏 L01-108
# if 微學分: False  學程
#  智慧生活空間資訊截取與運用效能化設計(Ⅰ) 梁明正 C01-B101 　 5,6,7
#
#  電力系統分析 寧家慶 C01-B101 10,11,12
#
#  控制系統 黃祥哲 B01-105 　 2,3,4
#
#  固態物理導論 施明昌
# if 微學分: False  先修
#  通訊原理 徐忠枝 C01-B103
#
#  計算機組織 賴智錦 C01-414 2,3,4
# if 微學分: False  學程
#  半導體技術導論 葉文冠 C01-B103
#
#  電腦輔助電路設計 張文騰 C01-104 　 2,3,4
#
#  元件與微系統概論 張文騰 C01-414 5,6,7
# if 微學分: False  學程
#  真空技術 馮瑞陽 C01-B101
#
#  科技英文 郭馨徽 C01-B101-1 　 5,6,7
#
#  智能金屬製造實務研討 吳志宏賴智錦郭馨徽 B01-104 6,7,8
# if 微學分: False  先修
#  數位訊號處理、系統設計與模擬 徐忠枝 C01-201
#
#  光電子學(二) 馮瑞陽 C01-B101
#
#  微波被動電路設計與分析 鄧卜華 C01-104
#
#  微波電路概論與量測基礎實務 吳松茂 C01-414
#
#  仿生計算 賴智錦 C01-414
# if 微學分: False  先修
#  射頻主動電路設計 龐一心 C01-104
#
#  深度學習與智慧型機械人 吳志宏 L01-108
# if 微學分: False  學程
#  智慧生活空間資訊截取與運用效能化設計(Ⅰ) 梁明正 C01-B101 　 5,6,7
#
#  控制系統 黃祥哲 B01-105 　 2,3,4
#
#  固態物理導論 施明昌
# if 微學分: False  學程
#  真空技術 馮瑞陽 C01-B101
#
#  科技英文 郭馨徽 C01-B101-1 　 5,6,7
#
#  智能金屬製造實務研討 吳志宏賴智錦郭馨徽 B01-104 6,7,8
#
#  高速數位系統設計實務 王陳肇 C01-B104
# if 微學分: False  先修
#  數位訊號處理、系統設計與模擬 徐忠枝 C01-201
#
#  電腦網路(二) 廖述銘 C01-104 　 5,6,7
#
#  微波濾波器設計 鄧卜華 C01-B101
#
#  電機機械 劉又齊 C01-202
#
#  高等元件分析 江德光 C01-B101-1
#
#  光電子學(二) 馮瑞陽 C01-B101
#
#  微波被動電路設計與分析 鄧卜華 C01-104
#
#  微波電路概論與量測基礎實務 吳松茂 C01-414
#
#  RFID 系統 梁明正 C01-202 5,6,7
#
#  仿生計算 賴智錦 C01-414
#
#  密碼學與實驗 徐忠枝 C01-201
# if 微學分: False  先修
#  射頻主動電路設計 龐一心 C01-104
#
#  Java物件導向程式設計 廖述銘 C01-104
#
#  類神經網路導論 李錫智 C01-B101-1
#
#  深度學習與智慧型機械人 吳志宏 L01-108
# if 微學分: False  學程
#  智慧生活空間資訊截取與運用效能化設計(Ⅰ) 梁明正 C01-B101 　 5,6,7
#
#  控制系統 黃祥哲 B01-105 　 2,3,4
#
#  固態物理導論 施明昌
# if 微學分: False  學程
#  真空技術 馮瑞陽 C01-B101
#
#  科技英文 郭馨徽 C01-B101-1 　 5,6,7
#
#  智能金屬製造實務研討 吳志宏賴智錦郭馨徽 B01-104 6,7,8
#
#  高速數位系統設計實務 王陳肇 C01-B104
# if 微學分: False  先修
#  數位訊號處理、系統設計與模擬 徐忠枝 C01-201
#
#  電腦網路(二) 廖述銘 C01-104 　 5,6,7
#
#  微波濾波器設計 鄧卜華 C01-B101
#
#  電機機械 劉又齊 C01-202
#
#  高等元件分析 江德光 C01-B101-1
#
#  光電子學(二) 馮瑞陽 C01-B101
#
#  微波被動電路設計與分析 鄧卜華 C01-104
#
#  微波電路概論與量測基礎實務 吳松茂 C01-414
#
#  RFID 系統 梁明正 C01-202 5,6,7
#
#  仿生計算 賴智錦 C01-414
#
#  密碼學與實驗 徐忠枝 C01-201
# if 微學分: False  先修
#  射頻主動電路設計 龐一心 C01-104
#
#  Java物件導向程式設計 廖述銘 C01-104
#
#  類神經網路導論 李錫智 C01-B101-1
#
#  深度學習與智慧型機械人 吳志宏 L01-108
# if 微學分: False  學程
#  智慧生活空間資訊截取與運用效能化設計(Ⅰ) 梁明正 C01-B101 　 5,6,7
# if 微學分: False  先修限修
#  建築設計(二)A 馬瑜嬪
# if 微學分: False  先修限修
#  建築設計(二)B 陳怡兆林光浩 H1--102
# if 微學分: False  先修限修
#  建築設計(二)C 郭書勝待公布 H1--110
# if 微學分: False  限修
#  建築設計表現法 馬瑜嬪 H1--108
# if 微學分: False  限修
#  數位創新設計(一) 馬瑜嬪 C02-B102
# if 微學分: False  禁止外加 限修
#  體育(二)-建築系 施長和
# if 微學分: False  先修學程
#  Unity 美術與開發實務 楊凱鳴陳怡兆 L01-610
# if 微學分: False  先修學程
#  Unreal 美術與開發實務 楊凱鳴陳怡兆 L01-610
# if 微學分: False  先修學程
#  EON腳本撰寫與開發實務 陳怡兆業界教師 L01-610
#
#  建築構造學(一) 陳怡兆 H1--101 　 3,4
#
#  近代建築史 陳逸杰 H1--101
#
#  建築物理環境 葉育君 H1--101
# if 微學分: False  先修限修
#  建築設計(四)A 葉育君 H1--108 1,2,3,4,5,6,7,8
# if 微學分: False  先修限修
#  建築設計(四)B 徐岩奇許家彰 H1--107 1,2,3,4,5,6,7,8
# if 微學分: False  先修限修
#  建築設計(四)C 待公布 　 1,2,3,4,5,6,7,8
# if 微學分: False  先修
#  建築設計(六)A 陳�C仁 　 　 1,2,3,4,5,6,7,8
# if 微學分: False  先修
#  建築設計(六)B 葉育君辜達齊 H1--107 　 1,2,3,4,5,6,7,8
#
#  建築法規 外校老師 H2--103
#
#  都市設計 曾梓峰 H1--101 3,4
#
#  台灣建築史 陳逸杰 H1--101
#
#  高齡環境實踐專題 曾梓峰 H1--101 5,6,7
#
#  數位創新設計(八)-城市資訊模型模擬應用 陳怡兆 H3--110 　 10,11
# if 微學分: False  限修
#  運動行銷學 孫美蓮 B01-207-4 　 5,6
# if 微學分: False  限修
#  專長術科(棒球)-Ⅱ 李坤哲 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(桌球)-Ⅱ 王明月 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(游泳)-Ⅱ 林季嬋 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(羽球)-Ⅱ 黃全成 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  人體解剖學 林季嬋 B01-207-4 1,2
# if 微學分: False  限修
#  飛盤運動 陳宗榮
# if 微學分: False  限修
#  專長術科(木球)-Ⅱ 葉天相 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  運動場地設施與管理 林政德 B01-207-4
# if 微學分: False  限修
#  體育活動設計 黃全成 B01-207-4 5,6
# if 微學分: False  限修
#  體適能(Ⅱ) 陳宗榮 B01-207-6其他教室
# if 微學分: False  限修
#  游泳(Ⅱ)A 葉天相
# if 微學分: False  禁止外加 限修
#  體育(二)-運技系 蔡義川 　 3,4
# if 微學分: False  限修
#  運動生物力學 陳宗榮 B01-207-6
# if 微學分: False  限修
#  專長術科(棒球)-Ⅳ 李坤哲 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(桌球)-Ⅳ 王明月 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(游泳)-Ⅳ 林季嬋 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(羽球)-Ⅳ 黃全成 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  體適能(Ⅱ) 陳宗榮 B01-207-4其他教室 3,4
# if 微學分: False  限修
#  游泳(Ⅱ)B 葉天相 　 　 5,6
# if 微學分: False  限修
#  運動科學講座 孫美蓮 B01-207-4 　 9,10
# if 微學分: False  限修
#  專長術科(木球)-IV 葉天相 　 　 1,2,3,4
# if 微學分: False  限修
#  運動團隊管理與領導 林政德 B01-207-4
# if 微學分: False  限修
#  肌力與體能訓練 陳宗榮 B01-207-6 1,2
# if 微學分: False  限修
#  桌球 王明月 　 5,6
# if 微學分: False  限修
#  田徑 葉天相
# if 微學分: False  限修
#  水上救生(Ⅱ) 葉天相
# if 微學分: False  限修
#  運動傷害與急救 陳宗榮 B01-207-6
# if 微學分: False  限修
#  運動教練學 李坤哲 B01-207-6
# if 微學分: False  限修
#  專長術科(棒球)-Ⅵ 李坤哲 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(桌球)-Ⅵ 王明月 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(游泳)-Ⅵ 林季嬋 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(羽球)-Ⅵ 黃全成 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(木球)-Ⅵ 葉天相 　 　 1,2,3,4
# if 微學分: False  限修
#  運動社會學 林政德 B01-207-4
# if 微學分: False  限修
#  運動貼紮理論與實務 陳宗榮 B01-207-4
# if 微學分: False  限修
#  運動法律 林政德 B01-207-4
# if 微學分: False  限修
#  羽球 黃全成 　 1,2
# if 微學分: False  限修
#  跆拳道 葉天相 K01-004
# if 微學分: False  限修
#  重量訓練(Ⅱ) 黃全成 　 3,4
# if 微學分: False  限修
#  籃球 陳宗榮
# if 微學分: False  限修
#  專長術科(棒球)-Ⅷ 李坤哲 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(桌球)-Ⅷ 王明月 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(游泳)-Ⅷ 林季嬋 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(羽球)-Ⅷ 黃全成 　其他教室 　 1,2,3,4
# if 微學分: False  限修
#  專長術科(木球)-Ⅷ 葉天相 　 　 1,2,3,4
# if 微學分: False  限修
#  運動選才學 李坤哲 B01-207-6 　 5,6
#
#  微積分(二) 童士恆 B01-103 1
#
#  工程統計學 袁菁 C01-106 2 3,4
#
#  工程圖學與電腦繪圖 吳明淏 L01-108
#
#  工程力學 俞肇球 C01-B103 　 5,6,7
#
#  環境化學 袁菁 C01-106 3,4 2
# if 微學分: False  禁止外加 限修
#  體育(二)-土環系A 王士仁
# if 微學分: False  限修
#  微積分(二) 吳宗芳 C02-408 　 2,3,4
# if 微學分: False  限修
#  工程統計學 袁菁 C01-413 　 5,6,7
# if 微學分: False  限修
#  工程圖學與電腦繪圖 吳明淏 L01-108
# if 微學分: False  限修
#  工程力學 陳純森 C01-B101
# if 微學分: False  限修
#  測量學 俞肇球 C01-B102
# if 微學分: False  限修
#  測量學實習 俞肇球 C01-501-1
#
#  環境分析及實驗〈二〉 林秋良 C01-113其他教室
#
#  土木工程實驗〈一〉 陳韋志 C01-101其他教室
#
#  工程數學〈二〉 吳明淏 B01-103 4
#
#  流體力學 甯蜀光 C01-B103其他教室 　 3,4
#
#  土壤力學 童士恆 B01-103 2,3
#
#  給水工程 連興隆 C01-B103 1 1,2
#
#  測量學實習 俞肇球 C01-501-1
# if 微學分: False  學程
#  材料機械性質 何文福 C01-B101-1 5,6,7
# if 微學分: False  限修
#  環境分析及實驗〈二〉 林秋良 C01-113其他教室
# if 微學分: False  限修
#  土木工程實驗(一) 陳韋志 C01-101其他教室
# if 微學分: False  限修
#  工程數學〈二〉 吳宗芳 C02-450
# if 微學分: False  限修
#  土壤力學 童士恆 C01-413 　 2,3,4
# if 微學分: False  限修
#  污水工程 連興隆 C01-106 5,6,7
#
#  結構學 蔡幸致 C01-B101其他教室
#
#  基礎工程 陳韋志 C01-106
#
#  廢棄物熱處理工程 林秋良 C01-413
#
#  鋼筋混凝土設計 陳振華 C01-B102-1 1,2,3
#
#  房屋結構設計 林庚達 C01-B102-1
#
#  專題研究〈二〉 甯蜀光 C01-106 　 Y
#
#  污水工程 連興隆 C01-B102 　 3,4,7
# if 微學分: False  限修
#  流體力學 甯蜀光 C01-413 2,3,4
# if 微學分: False  限修
#  結構學實例解析 劉紀宏 C01-B102
# if 微學分: False  限修
#  鋼結構設計 林庚達 C01-413
#
#  結構系統 蔡幸致 C01-B102-1
#
#  營建管理 蔡幸致 C01-B102-1
#
#  環境規劃與管理 甯蜀光 C01-B102其他教室 　 2
#
#  結構實驗 陳振華張惠雲 C01-B102-1 7,8,9
#
#  營建與環保法規實務 待公布 C01-B103 7,8
#
#  專題討論 陳韋志甯蜀光 C01-106
#
#  岩石力學 陳韋志 C01-106
#
#  有限元素法 俞肇球 C01-413
#
#  結構健康監測與試驗 陳振華 B01-B106 4,5 10
#
#  地震及防災工程 吳明淏 C01-B101 2,3
#
#  工程事件之鑑識與預防 陳純森 C01-B101
#
#  再生能源憑證制度：理論與實務 連興隆 C01-B102 2,3,4
#
#  人工智慧於土木與環境工程之應用 蔡幸致 L01-107
#
#  清潔生產 戴永惇 C01-B102-1
#
#  微積分(二) 謝永堂 C01-B104
#
#  普通物理實驗 楊證富 C01-211 　 10,11,12
# if 微學分: False  學程
#  普通化學(二) 王宗櫚 C01-105 　 3,4
# if 微學分: False  學程
#  化工與材料科學導論(二) 何文福陳文正 C01-105
#
#  電子電工學 楊證富 B01-104 1,2,3
#
#  物理化學(一) 陳文正 B01-104
# if 微學分: False  禁止外加 限修
#  體育(二)-化材系 黃郁玲
#
#  工程數學(二) 楊乾信 C01-105
#
#  材料化學實驗 蘇進成 C01-112其他教室 5,6,7
#
#  物理化學實驗 陳文正 C01-112其他教室
#
#  有機材料化學(二) 鍾宜璋 C01-105 2,3,4
#
#  高分子化學 王宗櫚 C01-B107-1
#
#  工程管理 林宏殷 C01-B101
#
#  化工與材料動力學 蘇進成 C01-105
# if 微學分: False  學程
#  物理冶金專題 呂正傑 C01-B101 　 2,3,4
# if 微學分: False  學程
#  儀器分析 陳文正 B01-103 　 5,6,7
#
#  化工與材料輸送現象(二) 楊乾信 C01-105
#
#  化工與材料實驗(II) 陳文正王宗櫚謝永堂鍾宜璋 C01-112其他教室
# if 微學分: False  學程
#  化工與材料熱力學(II) 呂正傑 B01-105
# if 微學分: False  學程
#  物理冶金專題 呂正傑 C01-B101 　 2,3,4
#
#  專題研究(二) 何文福王宗櫚謝永堂楊乾信陳文正鍾宜璋 C01-105 　 Y
#
#  智慧財產權保護法制與實用 待公布 C01-B104
#
#  複合材料 林東毅 C01-414 　 5,6,7
# if 微學分: False  學程
#  材料機械性質 何文福 C01-B101-1 5,6,7
#
#  石油化學工業實務 蘇進成待公布楊證富楊乾信 C01-105
#
#  化學感測器原理與應用 林宏殷 C01-B102-1
#
#  智慧財產權保護法制與實用 待公布 C01-B104
# if 微學分: False  學程
#  業界實習(三) 蘇進成楊證富王宗櫚楊乾信林東毅 C01-105 　 X
#
#  石油化學工業實務 蘇進成待公布楊證富楊乾信 C01-105
#
#  化學感測器原理與應用 林宏殷 C01-B102-1
# if 微學分: False  限修
#  專題討論(II) 楊證富王宗櫚 C01-105 　 5,6
#
#  生醫工程概論 劉開璽 C01-414
#
#  高等動力學 謝永堂 C01-B102 6,7,8
# if 微學分: False  學程
#  X-光繞射與晶體結構 呂正傑 C01-B101-1 2,3,4
#
#  光電材料與製程 楊證富 C01-B101 5,6,7
#
#  智能金屬理論與實務 林東毅 C01-414 　 2,3,4
#
#  實驗設計與數據處理 鍾宜璋 C01-B102
#
#  鈦合金材料特性與應用 何文福 C01-B102
#
#  精油化學與實務 林宏殷 C01-B101
# if 微學分: False  禁止外加 限修
#  體育(二)-法律系 施長和
#
#  民法債編總論(一) 張鈺光 L02-202
# if 微學分: False  限修
#  憲法(二) 紀振清 L02-102
#
#  哲學導論 賴志強 L02-101 　 3,4
#
#  法院組織法 賴志強 L02-101 5,6
#
#  刑法總則(二) 劉傳璟 L02-202
#
#  法律服務(二) 陳正根 L02-101
#
#  民法繼承 呂麗慧 L02-202
#
#  行政法總論(二) 陳正根 L02-102
# if 微學分: False  先修
#  日文(二) 林柏舟 L02-102 　 3,4
# if 微學分: False  先修限修
#  德文(二) 陳麗雅 L02-102 3,4
#
#  商事法總論暨公司法 李淑如 L02-101 　 7,8
#
#  民法債編各論(一) 林昭志 L02-102
#
#  民法物權(二) 謝志鵬 L02-202 5,6
# if 微學分: False  限修
#  刑法分則(二) 吳俊毅 L02-204
# if 微學分: False  限修
#  海商法 林昭志 L02-202
#
#  智慧財產權概論 康�Y銘 L02-101
# if 微學分: False  限修
#  民事訴訟法(二) 賴志強 L02-202 2,3,4
# if 微學分: False  限修
#  刑事訴訟法(二) 吳俊毅 L02-204
#
#  行政爭訟法 陳正根 L02-102
#
#  刑法實例演習 劉傳璟 L02-102 6,7
#
#  公法實例演習 紀振清 L02-102
#
#  校外實習 林昭志 　 X X
#
#  商事法實例演習 黃清溪 L02-102
#
#  國際私法(二) 謝志鵬 L02-202 7,8
#
#  海洋法 林昭志 L02-102 　 5,6
